# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# ## Data Science And Business Analytics Internship

# %% [markdown]
# ### Task #3 : Exploratory Data Analysis - Retail ###

# %% [markdown]
# ### Author : Supriyo Nagpal

# %% [markdown]
# ### Problem: Perform Exploratory Data Analysis (EDA) on Sample Superstore. As business manager, Find out the weak areas where you can work to make more profit. What all business problems you can derive by exploring the data?

# %% [markdown]
# **Dataset : https://bit.ly/3i4rbWl**

# %% [markdown]
# ### 1. Important Required Libraries

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns

# %% [markdown]
# ### 2. Read And Visualize

# %%
s_data = pd.read_excel(r"C:\Users\Priyanshi\Desktop\SampleSuperstore.xlsx")

# %%
s_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   float64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   float64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(5), object(8)
# memory usage: 1015.1+ KB

# %%
s_data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0      42420.0  South        Furniture    Bookcases  261.9600       2.0
# 1      42420.0  South        Furniture       Chairs  731.9400       3.0
# 2      90036.0   West  Office Supplies       Labels   14.6200       2.0
# 3      33311.0  South        Furniture       Tables  957.5775       5.0
# 4      33311.0  South  Office Supplies      Storage   22.3680       2.0
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
s_data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989      33180.0  South        Furniture  Furnishings   25.248       3.0
# 9990      92627.0   West        Furniture  Furnishings   91.960       2.0
# 9991      92627.0   West       Technology       Phones  258.576       2.0
# 9992      92627.0   West  Office Supplies        Paper   29.600       4.0
# 9993      92683.0   West  Office Supplies   Appliances  243.160       2.0
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
s_data.shape
# Out:
# (9994, 13)

# %%
s_data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
s_data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
s_data.duplicated().sum()
# Out:
# 17

# %%
s_data.drop_duplicates(inplace=True)
s_data.shape
# Out:
# (9977, 13)

# %%
s_data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
s_data.drop('Postal Code', axis=1 , inplace=True)

# %%
s_data.describe()
# Out:
#               Sales     Quantity     Discount      Profit
# count   9977.000000  9977.000000  9977.000000  9977.00000
# mean     230.148902     3.790719     0.156278    28.69013
# std      623.721409     2.226657     0.206455   234.45784
# min        0.444000     1.000000     0.000000 -6599.97800
# 25%       17.300000     2.000000     0.000000     1.72620
# 50%       54.816000     3.000000     0.200000     8.67100
# 75%      209.970000     5.000000     0.200000    29.37200
# max    22638.480000    14.000000     0.800000  8399.97600

# %% [markdown]
# ### 3. Represent Data

# %%
s_data.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %%
# Graph Between Category and Sub Category

plt.figure(figsize = (20, 15))
plt.bar('Sub-Category', 'Category', data = s_data)
plt.show()

# %%
print(s_data['State'].value_counts())
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
# graph of number of states 

plt.figure(figsize=(20,15))
sns.countplot(x = s_data['State'])
plt.xticks(rotation = 90)
plt.show()

# %%
# count the value of sub-category

print(s_data['Sub-Category'].value_counts())
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
# Graph the counts of Sub-category

plt.figure(figsize = (10,5))
sns.countplot(x = s_data['Sub-Category'])
plt.xticks(rotation = 90)
plt.show()

# %%
# check linearity 

plt.figure(figsize = (20,10))
sns.heatmap(s_data.corr(), annot = True)
plt.show()

# %%
# count of number of segment 

print(s_data['Segment'].value_counts())
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
# Graph of number of segment 

sns.countplot(x = s_data['Segment'])
plt.xticks(rotation = 90)
plt.show()

# %%
# graph of number of region 

sns.countplot(x = s_data['Region'])
plt.xticks(rotation = 90)
plt.show()

# %%
# graph of number of catagory 

sns.countplot(x = s_data['Category'])
plt.xticks(rotation = 90)
plt.show()

# %%
# Graph of number of sub-category

sns.countplot(x = s_data['Sub-Category'])
plt.xticks(rotation = 90)
plt.show()

# %%
# Graph between sub-category and Profit

plt.figure(figsize = (10,6))
sns.barplot('Sub-Category', 'Profit', data = s_data)
plt.xticks(rotation = 90)
plt.show()

# %%
# graph between discount and Profit

sns.lineplot(x= s_data['Discount'], y=s_data['Profit'],data = s_data, color = 'red', label = 'Discount')
plt.legend()
plt.grid()

# %%
# graph of sales, Quantity, Discount and profit

s_data.hist(bins=20, figsize = (20,15))
plt.show()

# %%
# visualizing relationship among feature depending on sub-category

sns.pairplot(s_data, hue = 'Sub-Category')
plt.show()

# %%
# visualizing among feature depending upon Category

sns.pairplot(s_data, hue = 'Category')
plt.show()

# %%
pd.DataFrame(s_data.groupby(['Ship Mode', 'Segment', 'Category', 'Sub-Category', 'State', 'Region'])['Quantity', 'Discount', 'Sales', 'Profit'].sum().reset_index())
# Out:
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# 2979  Standard Class  Home Office  Technology       Phones     Vermont
# 2980  Standard Class  Home Office  Technology       Phones    Virginia
# 2981  Standard Class  Home Office  Technology       Phones  Washington
# 2982  Standard Class  Home Office  Technology       Phones   Wisconsin
#
#        Region  Quantity  Discount     Sales    Profit
# 0        West       5.0      0.70   181.470 -320.5970
# ...

# %%
#Grouping and aggregation based on States

s_data.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76330.7891   38.241878  -325.5720  1906.4850   1996
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12601.6500  -25.665275 -2929.4845   874.9875    491
# ...

# %%
#Sales_Profit grouping based on State

Sales_Profit = s_data.groupby("State")["Profit"].sum()
Sales_Profit
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76330.7891
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12601.6500
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24428.0903
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
#Graph between State and Profit

plt.figure(figsize = (20, 10))
sns.barplot(x=Sales_Profit.index, y=Sales_Profit.values)
plt.ylabel("According to State Profit")
plt.xticks(rotation=90)
plt.show()

# %%
#Sales grouping based on State

Sales = s_data.groupby("State")["Sales"].sum()
Sales.plot.bar(figsize = (15, 10))
plt.show()

# %%
#Category grouping based on sales and profit

Category = s_data.groupby("Category")["Profit","Sales"].sum()
Category.plot.bar(figsize = (15, 10))
plt.show()

# %%
#Sub-Category grouping based on sales and profit

Sub_Category = s_data.groupby("Sub-Category")["Profit","Sales"].sum()
Sub_Category.plot.bar(figsize = (15, 10))
plt.show()

# %%
#State grouping based on sales and profit

State = s_data.groupby("State")["Profit","Sales"].sum()
State.plot.bar(figsize = (15, 10))
plt.show()

# %%
#Graph of Category based on Region

plt.figure(figsize = (20, 10))
sns.countplot(x= 'Category', hue = 'Region', data = s_data)
plt.xticks(rotation=90)
plt.show()

# %%
#Graph of Sub-Category based on Region

plt.figure(figsize = (20, 10))
sns.countplot(x= 'Sub-Category', hue = 'Region', data = s_data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 4. Conclusion
#
# 1.Profits and sales are highly correlated.
#
# 2.There is no correlation among quantity and profit.
#
# 3.In Category, Furniture has large number of sales, instead of making profit, it makes loss. So, there is need to limit the sales of Furniture.
#
# 4.In Sub-Category, Tables has has large number of sales, instead of making profit, it makes loss. So, there is need to limit the sales of Tables.
#
# 5.States like Texas, Ohio has huge sales but it makes big loss. So, there is need to reduce the sales in these states.
#
# 6.States like Michigan, Indiana, Virginia, Georgia makes good profit. So, sales can be increased in these states
